# %%
print('hola')
# Out:
# hola

# %% [markdown]
# #condicionales

# %%
imput = ingrese_su_edad 

edad_para_tomar = 18
edad_para_comprar = 21

#primera condicion
if edad_para_tomar < 18:
    print ('juguito nomas')

#segunda condicion
elif edad_para_tomar >= 18
    print ('podes tomar pero no comprar)
# Out:
#   Cell In[25], line 10
#     print ('podes tomar pero no comprar)
#            ^
# SyntaxError: unterminated string literal (detected at line 10)

# %%
temperatura= imput ('ingrese la temperatu

# %%
marcas = ['adidas',   ]

# %%
usuario = (input('ingrese una frase'))
for letra in usuario:
    if letra == 'o':
        print(usuario)
