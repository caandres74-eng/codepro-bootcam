# %%
print("hola mundo")
# Out:
# hola mundo

# %%
fruta="naranja"
print(fruta)

cantidad_de_fruta= 4
print(cantidad_de_fruta)
fruta="banana"
print(fruta)
# Out:
# naranja
# 4
# banana

# %%
edad = 28 # --> Integer
altura = 1.80 # --> float
nombre = "maggi"

# %% [markdown]
# crear variables con tu nombre edad

# %%
Nombre= "Esteban" 
edad= "29"
ciudad="fernando de la mora"
print (Nombre, edad, ciudad)
# Out:
# Esteban 29 fernando de la mora

# %%
producto= 'papas fritas'
costo_producto1= 15000
producto2= "cocacola"
costo_producto2= 14000
capital= 50000
dolar= 6700

#realizamos la suma
total= costo_producto2 + costo_producto1
print (total)

vuelto= capital - total
print (vuelto)

vuelto_dolar= round (vuelto/dolar,2)
print (vuelto_dolar)
# Out:
# 29000
# 21000
# 3.13

# %%
cantidad_de_manzanas= 352
cantidad_de_naranja= 547
cantidad_de_frutas= cantidad_de_manzanas + cantidad_de_naranja
print (cantidad_de_frutas)

frutas_vendidas=548
frutas_restantes= cantidad_de_frutas - frutas_vendidas
print (frutas_restantes)
# Out:
# 899
# 351

# %%
Nombre= 'Julio' 
Apellido='Ybañez'
print (f'hola mi nombre es {Nombre} y mi apellido es {Apellido}. mucho gusto')
# Out:
# hola mi nombre es Julio y mi apellido es Ybañez. mucho gusto

# %%
numero1=int(input('ingrese el primer numero: '))
numero2=int(input('ingrese el segundo numero: '))
suma= numero1 + numero2
print (f'la suma de los numeros es: ', suma)
# Out:
# la suma de los numeros es:  9

# %%
def preparar_cafe(proceso):
    print('calentar_agua', proceso) 
    print('preparar cafe', proceso)
    print('calentar agua', proceso)

preparar_cafe ('hacer cafe')
preparar_cafe ('hacer cafe')
preparar_cafe ('hacer cafe')
# Out:
# calentar_agua hacer cafe
# preparar cafe hacer cafe
# calentar agua hacer cafe
# calentar_agua hacer cafe
# preparar cafe hacer cafe
# calentar agua hacer cafe
# calentar_agua hacer cafe
# preparar cafe hacer cafe
# calentar agua hacer cafe

# %% [markdown]
# FUNCIONES CON PARAMETROS Y ARGUMENTOS

# %%
def mostrar(producto tipo, color, tamaño)
