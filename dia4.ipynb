# %% [markdown]
# class Perro:
#     #atributos de clase
#     cabeza = 1
#     patas = 4
#     especie = 'canina'
#     #atributo de instancia
#     def _init_(self,nombre, raza, color ):
#         self.nombre= nombre
#         self.raza= raza
#         self.color= color
#
# #creando un objeto - instanciar un objeto
# perro1 = Perro('Firulais','mestizo',"marron")
# perro2 = Perro("choco","delmer","blanco")
# perro3 = Perro("puppy","san bernardo","marron/blanco")
#
# print(perro1.especie)
# print(perro1.raza)
# print(perro1.color)

# %%
class leon:
    #atributos de clase
    cabeza = 1
    patas = 4
    melena = 1
    especie = 'felina'

    #atributo de instancia
    def__init__(self, nombre, raza, color):
    self.nombre= nombre
    self.raza= raza
    self.color= color  

leon1 = ('alex', 'felina', 'marron')
leon2 = ('raul', 'felina', 'marron')
leon3 = ('gabriel', 'felino', 'marron')

print(leon1.especie)
print(leon2.melena)
print(leon3.color)

# %%
class auto:
    
    

    def __init__(self, color, marca, ano):
        self.color = color 
        self.marca = marca
        self.ano = ano 
class hijo1:

# %%
#class Super heroe

#super fuerza = super_fuerza

#def __init__(self, super_fuerza)
    #self.super fuerza = super fuerza


#class Villano
#volar = volar
    #def __init__(self, volar)
    #self.volar = volar

#Super heroe('super_fuerza')
#Villano('volar')

 








class Super_heroe:

    def __init
